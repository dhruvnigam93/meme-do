# %%
# %load_ext autoreload
# %autoreload 2

# %%
from memedo.ai_agents.meme_agent import generate_meme_content
from memedo.ai_agents.summary_agent import get_match_summary
import json

# %%
from memedo.models.meme_template import all_memes


# Function to extract meme information
def get_meme_info(meme_class):
    meme_instance = meme_class()
    return {
        'id': meme_class.id,
        'name': meme_class.name,
        'description': meme_class.description,
        'instruction': meme_instance.instruction.strip(),
    }


# Collect meme information
memes_info = [get_meme_info(meme["class"]) for meme in all_memes]

match_summary = get_match_summary("india new zealand test match 17 october 2024")
print(match_summary)
# Out:
# Oh, dear heavens and all the cricketing gods What a catastrophe, a calamity, a CRICKETING APOCALYPSE we witnessed on October 17, 2024, at the M. Chinnaswamy Stadium in Bengaluru India, the mighty Indians, the pride of the subcontinent, collapsed like a house of cards in a hurricane. They were bowled out for a paltry, an abysmal, a downright SHAMEFUL 46 runs!
#
# Let's set the stage: the first day was a washout, thanks to the relentless rain that seemed to have a personal vendetta against cricket. But when play finally began on the second day, India's decision to bat first was akin to walking into a lion's den blindfolded and whistling 'The Lion Sleeps Tonight'.
#
# Rohit Sharma, the captain, the leader of the pack, went out for a mere 2 runs. Yes, TWO Virat Kohli and Sarfaraz Khan, the big guns, the stars of Indian cricket, were dismissed for DUCKS Zero, zilch, nada It was like watching a nightmare unfold in slow motion.
#
# ...

# %%
generated_memes = generate_meme_content(match_summary, memes_info, 5)['memes']
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 generated_memes = generate_meme_content(match_summary, memes_info, 5)['memes']
#
# File ~/Projects/hackaton/meme-do/memedo/ai_agents/meme_agent.py:65, in generate_meme_content(summary, memes_info, num_memes)
#      57         prompt += "-" * 50 + "\n"
#      59     prompt += f"""
#      60 Please choose {num_memes} meme templates from the list above that are most suitable for the match summary provided.
#      61 For each chosen meme, provide the inputs needed to create the meme, based on the match summary.
#      62 Also, provide a brief reasoning for choosing each meme template. Extra hundred dollars if it is controversial and offensive!
#      63 """
# ---> 65     response = client.beta.chat.completions.parse(
#      66         model="gpt-4o",
#      67         messages=[
# ...

# %%
generated_memes
# Out:
# [{'id': 9,
#   'meme_creation_input': '{"attempted_solution":"SubAir drainage system","failure":"rainy washout"}',
#   'reasoning': 'The drainage system was supposed to help with rain, but clearly, it just added to the comedy of errors, making it an ineffective solution.'},
#  {'id': 11,
#   'meme_creation_input': '{"depiction":"Indian batting lineup was a joke"}',
#   'reasoning': "India's batting was so disastrous, it was almost comedic. This template captures the essence of their performance."},
#  {'id': 8,
#   'meme_creation_input': '{"party_one":"Indian cricket fans","party_two":"Weather gods"}',
#   'reasoning': "Indian fans are likely blaming the weather for the team's poor performance, while the weather just laughs."},
#  {'id': 10,
#   'meme_creation_input': '{"opinion":"Rain is the real MVP of the match"}',
#   'reasoning': 'The rain has been the most consistent and dominant presence throughout the match, overshadowing the actual cricket.'},
#  {'id': 100,
# ...

# %%
created_memes = []
for meme_out in generated_memes:
    # instantiate the meme by taking approporiate class from al lmemes using id
    meme_class = next(meme["class"] for meme in all_memes if meme["id"] == meme_out["id"])
    meme_instance = meme_class()
    created_memes.append(meme_instance.create(json.loads(meme_out["meme_creation_input"])))

# %%
from PIL import Image
import matplotlib.pyplot as plt

outpath = "memedo/out/creations"

for meme_file_name in created_memes:
    # craete path by image name concat with outpath
    image_path = f"{outpath}/{meme_file_name}"
    image = Image.open(image_path)

    # Display the image
    plt.imshow(image)
    plt.axis('off')  # Hide the axis
    plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

outpath = "memedo/out/creations"

image_path = f"{outpath}/{'20241018132211046276.jpg'}"
image = Image.open(image_path)

# Display the image
plt.imshow(image)
plt.axis('off')  # Hide the axis
plt.show()

# from IPython.display import Image as gif_render, display
# display(gif_render(filename=f"{outpath}/{meme_file_name}"))

# %%
from memedo.models.meme_template import Buff_Doge_Vs_Cheems,Mujhe_Ghar_Jaana_Hai,Jethalal_Angry,Angry_Jethalal_Beating_Goli,Guy_Chilling,Disaster_PakFan,Confused,Thinking_About_Other_Women,Dhol_Rajpal_Yadav, Unintended_Damage
a = Unintended_Damage()
meme_text = {}
meme_text["who"] = "ved prakash in team dinner after celebrating the new project completion"
file_name = a.create(meme_text=meme_text)

# %%
from PIL import Image
import matplotlib.pyplot as plt

outpath = "memedo/out/creations"

image_path = f"{outpath}/{file_name}"
image = Image.open(image_path)

# Display the image
plt.imshow(image)
plt.axis('off')  # Hide the axis
plt.show()

# from IPython.display import Image as gif_render, display
# display(gif_render(filename=f"{outpath}/{meme_file_name}"))

# %%
from IPython.display import Image as gif_render, display
display(gif_render("memedo/out/creations/20241018122409158695.gif"))
